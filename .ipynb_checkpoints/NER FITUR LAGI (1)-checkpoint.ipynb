# %%
import string
import pandas as pd
import numpy as np
from pprint import pprint
from sklearn.pipeline import Pipeline
from seqeval.metrics import classification_report as seq_met
from sklearn.metrics import classification_report as skl_met
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction import DictVectorizer
from sklearn.naive_bayes import MultinomialNB

# %% [markdown]
# ## Read Test and Train Data

# %%
df_train = pd.read_excel("Datasets/200_Hadits.xlsx", sheet_name="train")
df_test = pd.read_excel("Datasets/200_Hadits.xlsx", sheet_name="test")

# df_train = pd.read_csv('100_dataset - 100.csv', encoding = "ISO-8859-1")
# df_test = pd.read_csv('100_test_2.csv', encoding = "ISO-8859-1")

# %%
# Count the tokens for each entity
df_test.groupby('entity').size().reset_index(name='counts')
# Out:
#   entity  counts
# 0  B-LOC       6
# 1  B-PER     674
# 2  I-LOC       2
# 3  I-PER    1391
# 4      O    7793

# %%
# Count the tokens for each entity
df_train.groupby('entity').size().reset_index(name='counts')
# Out:
#   entity  counts
# 0  B-LOC      24
# 1  B-PER    1564
# 2  I-LOC      22
# 3  I-PER    3067
# 4      O   16466

# %% [markdown]
# ## Grouping Tokens by Hadith

# %%
def sencentes_getter(data):
    agg_func = lambda s: [(s.name, t, p, e) for t, p, e in zip(s['token'].values.tolist(), 
                                                           s['pos'].values.tolist(), 
                                                           s['entity'].values.tolist())]
    grouped = data.groupby('title').apply(agg_func)
    sentences = [s for s in grouped]
    
    return sentences

# %%
train_sents = sencentes_getter(df_train)
test_sents = sencentes_getter(df_test)

# %% [markdown]
# ## Feature Extraction

# %%
def word2features(sent, i):
        word = sent[i][1]
        postag = sent[i][2]

        features = {
            'bias': 1.0, 
            'word': word,
            'word.istitle()': word.istitle(),
            'postag': postag,
            
            'word_pls_1': '',
            'word_pls_1.istitle()': False,
            'postag_pls_1': '',
            
            'word_min_1': '',
            'word_min_1.istitle()': False,
            'postag_min_1': '',
            
            'BOS': True if i == 0 else False,
            'EOS': True if i == len(sent)-1 else False,
        }
        
        
        if i < len(sent)-1:
            word_pls_1 = sent[i+1][1]
            postag_pls_1 = sent[i+1][2]
            features.update({
                'word_pls_1': word_pls_1,
                'word_pls_1.istitle()': word_pls_1.istitle(),
                'postag_pls_1': postag_pls_1
            })
        if i > 0:
            word_min_1 = sent[i-1][1]
            postag_min_1 = sent[i-1][2]
            features.update({
                'word_min_1': word_min_1,
                'word_min_1.istitle()': word_min_1.istitle(),
                'postag_min_1': postag_min_1
            })
        
        return features

def sent2features(sent):  
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
#     print(sent)
    return [label for title, token, postag, label in sent]

def sent2labelspred(sent):
    return [pred for title, token, postag, label, pred in sent]

# %%
# pd.DataFrame(X_train)

# %%
# Training
X_train = [x for s in train_sents for x in sent2features(s)]
y_train = [y for s in train_sents for y in sent2labels(s)]

# Test
X_test = [x for s in test_sents for x in sent2features(s)]
y_test = [y for s in test_sents for y in sent2labels(s)]

# %%
classes = ['B-LOC', 'B-PER', 'I-LOC', 'I-PER', 'O']
new_classes = classes.copy()
new_classes.pop()
# Out:
# 'O'

# %% [markdown]
# ## Training Model

# %%
clf = Pipeline([
    ('vectorizer', DictVectorizer(sparse=False)),
    ('classifier', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))
])

clf.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('vectorizer', DictVectorizer(dtype=<class 'numpy.float64'>, separator='=', sort=True,
#         sparse=False)), ('classifier', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

# %%
print("Accuracy of Training:")
print(clf.score(X_train, y_train))
print("Accuracy of Validation:")
print(clf.score(X_test, y_test))

print(skl_met(y_test, clf.predict(X_test), labels=new_classes))
# Out:
# Accuracy of Training:
# 0.9756893534503145
# Accuracy of Validation:
# 0.9754713156294345
#               precision    recall  f1-score   support
#
#        B-LOC       0.00      0.00      0.00         6
#        B-PER       0.91      0.92      0.91       674
#        I-LOC       0.00      0.00      0.00         2
#        I-PER       0.92      0.98      0.95      1391
#
#    micro avg       0.92      0.95      0.94      2073
#    macro avg       0.46      0.47      0.47      2073
# weighted avg       0.92      0.95      0.93      2073
# /home/ghost/anaconda3/envs/Playgrounds/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
df_result = df_test.copy()
df_result['predicted'] = clf.predict(X_test)
df_result_grouped = df_result.groupby('title')

y_pred = df_result_grouped['predicted']
y_true = df_result_grouped['entity']

y_grouped_pred = [p[1].tolist() for p in y_pred]
y_grouped_true = [p[1].tolist() for p in y_true]



print(seq_met(y_grouped_true, y_grouped_pred))
# ne_per = 2251
# ne_loc = 41
print("Training Data")
print("Jumlah Hadits: ", 140)
print("Jumlah Entitas PER: ", 1572)
print("Jumlah Entitas LOC: ", 33)
print("\n")
print("Test Data")
print("Jumlah Hadits: ", 60)
print("Jumlah Entitas PER: ", 679)
print("Jumlah Entitas LOC: ", 8)
# Out:
#              precision    recall  f1-score   support
#
#         PER       0.81      0.87      0.84       679
#         LOC       0.00      0.00      0.00         8
#
# avg / total       0.80      0.86      0.83       687
#
# Training Data
# Jumlah Hadits:  140
# Jumlah Entitas PER:  1572
# Jumlah Entitas LOC:  33
#
#
# Test Data
# Jumlah Hadits:  60
# Jumlah Entitas PER:  679
# Jumlah Entitas LOC:  8

# %%
def get_predicted_sent(data):
    func = lambda s: [(s.name, t, p) for t, p in zip(s['token'].values.tolist(),
                                                     s['predicted'].values.tolist())]
    groupedx = data.groupby('title').apply(func)
    sents = [g for g in groupedx]
    
    return sents

# %%
pred_sents = get_predicted_sent(df_result)

def names_by_hadith(data):
    titl = {}
    sent_nes = []

    for sent in data:
        for i in range(len(sent)):
            if sent[i][-1] == 'B-PER':
                ne = []
                while sent[i][-1] != 'O':
                    ne.append(sent[i][1])
                    if i<len(sent)-1:
                        i+=1
                    else:
                        break
                str_name = "".join([i+" " if not i.startswith("'") and i not in string.punctuation else i for i in ne]).strip()
                if str_name not in sent_nes:
                    sent_nes.append(str_name)
        titl[sent[0][0]] = sent_nes.copy()
        sent_nes.clear()
    return titl

# pprint(names_by_hadith(pred_sents))

# %%
def hadith_by_name(data):
    nms = {}
    for sent in data:
        for i in range(len(sent)):
            if sent[i][-1] == 'B-PER':
                ne = []
                while sent[i][-1] != 'O':
                    ne.append(sent[i][1])
                    if i<len(sent)-1:
                        i+=1
                    else:
                        break
                str_name = "".join([i+" " 
                                    if not i.startswith("'") and i not in string.punctuation 
                                    else i for i in ne]).strip().title()
                if str_name not in nms:
                    nms[str_name] = [sent[0][0]]
                else:
                    if sent[0][0] not in nms[str_name]:
                        nms[str_name].append(sent[0][0])
    return nms

pprint(hadith_by_name(pred_sents))
# Out:
# {"'Abbad Ibnu Mansur": ['Hadits Darimi Nomor 11'],
#  "'Amr Bin Abu Qais": ['Hadits Darimi Nomor 10'],
#  "'Amru Bin Huraits": ['Hadits Ahmad Nomor 12'],
#  "'Amru Bin Yahya Al Mazini": ['Hadits Malik Nomor 13'],
#  "'Atha Bin Yazid": ['Hadits Nasai Nomor 21'],
#  "'Atha `": ['Hadits Darimi Nomor 10'],
#  "'Aun Bin Abdullah": ['Hadits Ibnu Majah Nomor 19'],
#  "'Dulukus Syamsi": ['Hadits Malik Nomor 16'],
#  "'Ubaidah Bin Humaid": ['Hadits Nasai Nomor 13'],
#  "'Utbah Bin 'Abd As Sulami Bahwa": ['Hadits Darimi Nomor 13'],
#  'Aban Bin Shalih': ['Hadits Abu Daud Nomor 12'],
#  'Aban Bin Utsman': ['Hadits Ahmad Nomor 378'],
#  'Abbad Ibnu Mansur': ['Hadits Darimi Nomor 11'],
#  'Abdah Bin Sulaiman': ['Hadits Tirmidzi Nomor 11',
#                         'Hadits Tirmidzi Nomor 22',
#                         'Hadits Tirmidzi Nomor 23'],
#  "Abdul 'Aziz Bin Shuhaib": ['Hadits Bukhari Nomor 14'],
#  "Abdul A'La": ['Hadits Abu Daud Nomor 16'],
#  'Abdul Karim': ['Hadits Tirmidzi Nomor 12'],
#  'Abdul Karim Bin Abul Mukhariq': ['Hadits Tirmidzi Nomor 12'],
#  'Abdul Malik Bin Al Harits': ['Hadits Ahmad Nomor 10'],
#  'Abdul Muthalib': ['Hadits Ahmad Nomor 3'],
#  'Abdul Wahhab Ats Tsaqafi': ['Hadits Bukhari Nomor 15',
#                               'Hadits Ibnu Majah Nomor 17'],
#  'Abdullah': ['Hadits Ahmad Nomor 14'],
#  "Abdullah Bin 'Amru": ['Hadits Tirmidzi Nomor 22'],
#  "Abdullah Bin 'Umar": ['Hadits Malik Nomor 21'],
#  'Abdullah Bin Abdullah Bin Jabar': ['Hadits Bukhari Nomor 16'],
#  'Abdullah Bin Abu Syaibah': ['Hadits Ahmad Nomor 14'],
#  'Abdullah Bin Az Zubair': ['Hadits Ibnu Majah Nomor 15'],
#  'Abdullah Bin Handlallah': ['Hadits Tirmidzi Nomor 22'],
#  'Abdullah Bin Hasyim Al -Abdi': ['Hadits Muslim Nomor 13'],
#  'Abdullah Bin Imran': ['Hadits Darimi Nomor 14'],
#  "Abdullah Bin Mas'Ud": ['Hadits Ibnu Majah Nomor 19',
#                          'Hadits Tirmidzi Nomor 12'],
#  'Abdullah Bin Mughaffal': ['Hadits Ibnu Majah Nomor 17'],
#  'Abdullah Bin Muhammad Bin Abu Syaibah': ['Hadits Ahmad Nomor 14'],
#  'Abdullah Bin Umar': ['Hadits Malik Nomor 16'],
#  'Abdullah Bin Umar Bin Khathab': ['Hadits Malik Nomor 15'],
#  'Abdullah Bin Zubair': ['Hadits Ibnu Majah Nomor 15'],
#  'Abdurrahman Bin Harmalah': ['Hadits Tirmidzi Nomor 25'],
#  'Abdurrahman Bin Hasanah': ['Hadits Tirmidzi Nomor 12'],
#  'Abdussalam Bin Harb': ['Hadits Abu Daud Nomor 13'],
#  "Abidah Bin 'Amru As Salmani": ['Hadits Tirmidzi Nomor 13'],
#  "Abu 'Amru Hafsh Bin Umar": ['Hadits Ibnu Majah Nomor 17'],
#  "Abu 'Imran Al Jauny": ['Hadits Nasai Nomor 14'],
#  'Abu Abdul Karim': ['Hadits Tirmidzi Nomor 13'],
#  "Abu Abdurrahman Al Muqri '": ['Hadits Ahmad Nomor 10'],
#  'Abu Al -': ['Hadits Muslim Nomor 15'],
#  'Abu Al Walid': ['Hadits Bukhari Nomor 16'],
#  'Abu Al Yaman': ['Hadits Bukhari Nomor 13', 'Hadits Bukhari Nomor 17'],
#  'Abu Ali Al Hanafi': ['Hadits Abu Daud Nomor 18'],
#  'Abu Ammar Al Husain Bin Huraib': ['Hadits Tirmidzi Nomor 13'],
#  'Abu Asma `Ar Rahabi': ['Hadits Ibnu Majah Nomor 10'],
#  'Abu At Taiyyah': ['Hadits Ahmad Nomor 12'],
#  'Abu Ath Thufail': ['Hadits Ahmad Nomor 14'],
#  'Abu Ayub Al Anshari': ['Hadits Nasai Nomor 22'],
#  'Abu Ayyub': ['Hadits Muslim Nomor 15', 'Hadits Tirmidzi Nomor 22'],
#  'Abu Ayyub Al Anshari': ['Hadits Nasai Nomor 21'],
#  'Abu Ayyub As Sikhtiyani': ['Hadits Tirmidzi Nomor 12'],
#  'Abu Az Zanad': ['Hadits Bukhari Nomor 13'],
#  'Abu Bakar': ['Hadits Abu Daud Nomor 15',
#                'Hadits Ahmad Nomor 10',
#                'Hadits Ahmad Nomor 11',
#                'Hadits Ahmad Nomor 14',
#                'Hadits Ahmad Nomor 3'],
#  'Abu Bakar Ash Shiddiq': ['Hadits Ahmad Nomor 10',
#                            'Hadits Ahmad Nomor 12',
#                            'Hadits Tirmidzi Nomor 22'],
#  'Abu Bakar Bin Abu Syaibah': ['Hadits Muslim Nomor 10',
#                                'Hadits Muslim Nomor 15'],
#  'Abu Bakar Bin Ishaq': ['Hadits Muslim Nomor 16'],
#  'Abu Bakr Bin Al Khallad Al Bahili': ['Hadits Ibnu Majah Nomor 19'],
#  'Abu Bakr Bin Huwaithib': ['Hadits Tirmidzi Nomor 25'],
#  'Abu Daud': ['Hadits Darimi Nomor 14'],
#  'Abu Dawud': ['Hadits Abu Daud Nomor 13',
#                'Hadits Abu Daud Nomor 15',
#                'Hadits Abu Daud Nomor 18'],
#  'Abu Dzar': ['Hadits Darimi Nomor 14'],
#  "Abu Dzar Al Ghifari Radliyallahu'Anhu": ['Hadits Darimi Nomor 14'],
#  'Abu Hayyan': ['Hadits Muslim Nomor 10'],
#  'Abu Hayyan At -Taimi': ['Hadits Muslim Nomor 10'],
#  'Abu Hurairah': ['Hadits Ahmad Nomor 10',
#                   'Hadits Bukhari Nomor 13',
#                   'Hadits Malik Nomor 14',
#                   'Hadits Muslim Nomor 10',
#                   'Hadits Muslim Nomor 11',
#                   'Hadits Muslim Nomor 16',
#                   'Hadits Nasai Nomor 11',
#                   'Hadits Tirmidzi Nomor 22',
#                   'Hadits Tirmidzi Nomor 24',
#                   'Hadits Tirmidzi Nomor 25'],
#  "Abu Idris 'Aidzullah Bin Abdullah": ['Hadits Bukhari Nomor 17'],
#  'Abu Isa': ['Hadits Tirmidzi Nomor 11',
#              'Hadits Tirmidzi Nomor 12',
#              'Hadits Tirmidzi Nomor 13',
#              'Hadits Tirmidzi Nomor 22',
#              'Hadits Tirmidzi Nomor 23',
#              'Hadits Tirmidzi Nomor 24',
#              'Hadits Tirmidzi Nomor 25'],
#  'Abu Isa Ar Ramli': ['Hadits Abu Daud Nomor 13'],
#  'Abu Ishaq': ['Hadits Ahmad Nomor 3', 'Hadits Muslim Nomor 15'],
#  'Abu Kuraib': ['Hadits Tirmidzi Nomor 22'],
#  'Abu Marwan Muhammad Bin Utsman Al Utsmani': ['Hadits Ibnu Majah Nomor 14'],
#  'Abu Musa': ['Hadits Nasai Nomor 4', 'Hadits Tirmidzi Nomor 22'],
#  'Abu Qilabah': ['Hadits Bukhari Nomor 15',
#                  'Hadits Darimi Nomor 11',
#                  'Hadits Ibnu Majah Nomor 10'],
#  "Abu Sa'Id": ['Hadits Tirmidzi Nomor 25'],
#  'Abu Salamah': ['Hadits Tirmidzi Nomor 22',
#                  'Hadits Tirmidzi Nomor 23',
#                  'Hadits Tirmidzi Nomor 24'],
#  'Abu Salamah Bin Abdurrahman': ['Hadits Malik Nomor 14'],
#  'Abu Shalih': ['Hadits Darimi Nomor 15'],
#  'Abu Suhail': ['Hadits Muslim Nomor 12'],
#  'Abu Syaibah': ['Hadits Abu Daud Nomor 15'],
#  'Abu Tsifal Al Murri': ['Hadits Tirmidzi Nomor 25'],
#  'Abu Usamah': ['Hadits Darimi Nomor 12'],
#  'Abu Utsman An Nahdi': ['Hadits Darimi Nomor 12'],
#  'Abu Wa `Il': ['Hadits Tirmidzi Nomor 13'],
#  "Abu Zur'Ah": ['Hadits Muslim Nomor 11', 'Hadits Muslim Nomor 16'],
#  "Abu Zur'Ah Bin Amru Bin Jarir": ['Hadits Muslim Nomor 10'],
#  'Abul Walid Ahmad Bin Bakkar Ad Dimasqi': ['Hadits Tirmidzi Nomor 24'],
#  'Adam': ['Hadits Bukhari Nomor 14'],
#  'Adh Dhahhak Bin Utsman': ['Hadits Abu Daud Nomor 15'],
#  'Affan': ['Hadits Muslim Nomor 16'],
#  'Ahmad Bin Al Walid': ['Hadits Abu Daud Nomor 13'],
#  'Ahmad Bin Hanbal': ['Hadits Tirmidzi Nomor 24'],
#  'Ahmad Bintsabit Al Jadari': ['Hadits Ibnu Majah Nomor 17'],
#  'Aisyah': ['Hadits Abu Daud Nomor 17',
#             'Hadits Ibnu Majah Nomor 14',
#             'Hadits Tirmidzi Nomor 12',
#             'Hadits Tirmidzi Nomor 22',
#             'Hadits Tirmidzi Nomor 24',
#             'Hadits Tirmidzi Nomor 25'],
#  'Aku': ['Hadits Ibnu Majah Nomor 16'],
#  'Al': ['Hadits Muslim Nomor 13'],
#  "Al 'Anqazi": ['Hadits Ahmad Nomor 3'],
#  "Al A'Masy": ['Hadits Abu Daud Nomor 13',
#                'Hadits Darimi Nomor 15',
#                'Hadits Tirmidzi Nomor 13'],
#  "Al A'Raj": ['Hadits Bukhari Nomor 13'],
#  'Al Afiyah': ['Hadits Ahmad Nomor 10'],
#  "Al Auza'I": ['Hadits Tirmidzi Nomor 24'],
#  'Al Bahiy': ['Hadits Abu Daud Nomor 17'],
#  "Al Barra '": ['Hadits Ahmad Nomor 3'],
#  "Al Barra 'Bin 'Azib": ['Hadits Ahmad Nomor 3'],
#  'Al Fa `Fa': ['Hadits Abu Daud Nomor 17'],
#  'Al Furqon': ['Hadits Darimi Nomor 10'],
#  'Al Hasan': ['Hadits Abu Daud Nomor 16'],
#  "Al Hasan Bin 'Ali": ['Hadits Darimi Nomor 12'],
#  'Al Hasan Bin Ali Al Hulwani': ['Hadits Tirmidzi Nomor 25'],
#  'Al Jarud': ['Hadits Tirmidzi Nomor 13'],
#  "Al Laist Bin Sa'D": ['Hadits Ibnu Majah Nomor 15'],
#  'Al Miqdam Bin Syuraih': ['Hadits Tirmidzi Nomor 12'],
#  'Al Mufashal': ['Hadits Ahmad Nomor 3'],
#  "Al Mughirah Bin Subai '": ['Hadits Ahmad Nomor 12'],
#  "Al Mughirah Bin Syu'Bah": ['Hadits Tirmidzi Nomor 13'],
#  'Al Muhajir Bin Qunfudz': ['Hadits Abu Daud Nomor 16'],
#  'Al Qasim Bin Muhammad': ['Hadits Ibnu Majah Nomor 14'],
#  "Al Walid Bin Jumai '": ['Hadits Ahmad Nomor 14'],
#  'Al Walid Bin Muslim': ['Hadits Tirmidzi Nomor 24'],
#  'Ali': ['Hadits Tirmidzi Nomor 22'],
#  'Ali Bin Hujr': ['Hadits Nasai Nomor 13', 'Hadits Tirmidzi Nomor 12'],
#  'Ali Bin Mushir': ['Hadits Darimi Nomor 15'],
#  'Allah': ['Hadits Ibnu Majah Nomor 18', 'Hadits Muslim Nomor 13'],
#  "Amru Bin 'Aun": ['Hadits Abu Daud Nomor 13'],
#  'Amru Bin Muhammad Bin Bukair': ['Hadits Muslim Nomor 13'],
#  'Anas': ['Hadits Abu Daud Nomor 18',
#           'Hadits Bukhari Nomor 12',
#           'Hadits Bukhari Nomor 14',
#           'Hadits Bukhari Nomor 16',
#           'Hadits Muslim Nomor 13',
#           'Hadits Tirmidzi Nomor 22',
#           'Hadits Tirmidzi Nomor 25'],
#  'Anas Bahwasannya Abu Bakar': ['Hadits Ahmad Nomor 11'],
#  'Anas Bin Malik': ['Hadits Abu Daud Nomor 13',
#                     'Hadits Bukhari Nomor 15',
#                     'Hadits Muslim Nomor 13',
#                     'Hadits Nasai Nomor 14'],
#  'Anshar Mendebat Az Zubair': ['Hadits Ibnu Majah Nomor 15'],
#  'As Sakinah': ['Hadits Darimi Nomor 10'],
#  'Ashim Bin Badalah': ['Hadits Tirmidzi Nomor 13'],
#  "Asy Syafi'I": ['Hadits Tirmidzi Nomor 24'],
#  'Atha Bin Yazid': ['Hadits Nasai Nomor 22'],
#  'Ayahnya': ['Hadits Abu Daud Nomor 17'],
#  'Ayyub': ['Hadits Bukhari Nomor 15',
#            'Hadits Darimi Nomor 11',
#            'Hadits Ibnu Majah Nomor 17'],
#  'Az Zubair': ['Hadits Ibnu Majah Nomor 15'],
#  'Az Zuhri': ['Hadits Abu Daud Nomor 18',
#               'Hadits Bukhari Nomor 17',
#               'Hadits Ibnu Majah Nomor 16',
#               'Hadits Nasai Nomor 21',
#               'Hadits Tirmidzi Nomor 24'],
#  'Bahir': ['Hadits Darimi Nomor 13'],
#  'Bahwasannya': ['Hadits Ahmad Nomor 12'],
#  'Bahz': ['Hadits Muslim Nomor 13'],
#  'Bani Abdud Dar': ['Hadits Ahmad Nomor 3'],
#  'Bani Fihri': ['Hadits Ahmad Nomor 3'],
#  'Bani Haritsah': ['Hadits Ahmad Nomor 3'],
#  'Bani Najar Paman Abdul Muthalib': ['Hadits Ahmad Nomor 3'],
#  "Bani Sa'D Bin Bakr": ['Hadits Darimi Nomor 13'],
#  'Bapaknya': ['Hadits Ibnu Majah Nomor 14',
#               'Hadits Ibnu Majah Nomor 18',
#               'Hadits Tirmidzi Nomor 12',
#               'Hadits Tirmidzi Nomor 25'],
#  'Baqiyyah': ['Hadits Darimi Nomor 13'],
#  "Barro '": ['Hadits Ahmad Nomor 3'],
#  'Bathaa': ['Hadits Darimi Nomor 12'],
#  'Beliau': ['Hadits Nasai Nomor 4'],
#  'Bilal': ['Hadits Malik Nomor 22'],
#  "Bisyr Bin Mu'Adz Al Aqadi": ['Hadits Tirmidzi Nomor 25'],
#  'Bisyr Ibnul Mufadldlal': ['Hadits Tirmidzi Nomor 25'],
#  'Burd Bin Sinan': ['Hadits Ibnu Majah Nomor 18'],
#  'Busr Bin Artha `Ah': ['Hadits Tirmidzi Nomor 24'],
#  'Empat': ['Hadits Nasai Nomor 14'],
#  'Fathimah': ['Hadits Ahmad Nomor 14'],
#  'Ghundar': ['Hadits Nasai Nomor 22'],
#  'Habib Bin Yasar': ['Hadits Nasai Nomor 13'],
#  'Hadits Aisyah': ['Hadits Tirmidzi Nomor 12'],
#  'Hai Abul Walid': ['Hadits Ibnu Majah Nomor 18'],
#  'Hai Zubair': ['Hadits Ibnu Majah Nomor 15'],
#  'Haiwah Bin Syuraih': ['Hadits Ahmad Nomor 10'],
#  'Hammad Bin Abu Sulaiman': ['Hadits Tirmidzi Nomor 13'],
#  'Hammam': ['Hadits Abu Daud Nomor 18', 'Hadits Ahmad Nomor 11'],
#  'Handzalah Bin Abu Sufyan': ['Hadits Nasai Nomor 12'],
#  'Hannad': ['Hadits Tirmidzi Nomor 11',
#             'Hadits Tirmidzi Nomor 13',
#             'Hadits Tirmidzi Nomor 23'],
#  'Hari Kiamat': ['Hadits Muslim Nomor 10', 'Hadits Muslim Nomor 11'],
#  'Harits Bin Miskin': ['Hadits Nasai Nomor 12'],
#  'Hasyim Bin Al -Qasim Abu An -': ['Hadits Muslim Nomor 13'],
#  "Hisyam Bin 'Ammar": ['Hadits Ibnu Majah Nomor 10',
#                        'Hadits Ibnu Majah Nomor 18'],
#  "Hisyam Bin 'Urwah": ['Hadits Ahmad Nomor 377'],
#  'Hudhain Bin Al Mundzir Abi Sasan': ['Hadits Abu Daud Nomor 16'],
#  'Hudzaifah': ['Hadits Tirmidzi Nomor 13', 'Hadits Tirmidzi Nomor 22'],
#  "Husain Al Mu'Alim": ['Hadits Bukhari Nomor 12'],
#  "Ibnu 'Ajlan": ['Hadits Ibnu Majah Nomor 19'],
#  "Ibnu 'Ulayyah": ['Hadits Bukhari Nomor 14'],
#  'Ibnu Abbas': ['Hadits Tirmidzi Nomor 22'],
#  "Ibnu Abi 'Arubah": ['Hadits Ahmad Nomor 12'],
#  'Ibnu Abi Za `Idah': ['Hadits Abu Daud Nomor 17'],
#  'Ibnu Abu Salith': ['Hadits Malik Nomor 13'],
#  'Ibnu Abu Syaibah': ['Hadits Muslim Nomor 15'],
#  'Ibnu Al -': ['Hadits Muslim Nomor 11'],
#  'Ibnu Juraij': ['Hadits Abu Daud Nomor 18'],
#  "Ibnu Mas'Ud": ['Hadits Darimi Nomor 12'],
#  "Ibnu Mas'Ud Radliyallahu'Anhu": ['Hadits Darimi Nomor 12'],
#  'Ibnu Sulaiman': ['Hadits Nasai Nomor 14'],
#  'Ibnu Syihab': ['Hadits Ibnu Majah Nomor 15',
#                  'Hadits Malik Nomor 14',
#                  'Hadits Malik Nomor 22',
#                  'Hadits Nasai Nomor 22'],
#  'Ibnu Ulayyah': ['Hadits Muslim Nomor 10'],
#  'Ibnu Umar': ['Hadits Abu Daud Nomor 15',
#                'Hadits Ibnu Majah Nomor 16',
#                'Hadits Muslim Nomor 20',
#                'Hadits Nasai Nomor 12',
#                'Hadits Tirmidzi Nomor 11',
#                'Hadits Tirmidzi Nomor 12',
#                'Hadits Tirmidzi Nomor 22',
#                'Hadits Tirmidzi Nomor 24'],
#  "Ibnu Umar Bahwasanya Nabi Shallallahu 'Alaihi Wasallam": ['Hadits Abu Daud '
#                                                             'Nomor 13'],
#  'Ibnu Ummi Maktum': ['Hadits Ahmad Nomor 3'],
#  'Ibnu Wahb': ['Hadits Nasai Nomor 12'],
#  'Ibrahim': ['Hadits Tirmidzi Nomor 13'],
#  "Ibrahim Bin Sa'D Bin Ibrahim Bin Abdurrahman Bin Auf": ['Hadits Ibnu Majah '
#                                                           'Nomor 14'],
#  "Ibrahin An Nakha'I": ['Hadits Tirmidzi Nomor 13'],
#  'Ibu Asuhku': ['Hadits Darimi Nomor 13'],
#  'Imam Ahmad Bin Hambal': ['Hadits Tirmidzi Nomor 25'],
#  'Ishaq': ['Hadits Tirmidzi Nomor 24', 'Hadits Tirmidzi Nomor 25'],
#  'Ishaq Bin Qabishah': ['Hadits Ibnu Majah Nomor 18'],
#  'Ishaq Bin Sulaiman': ['Hadits Darimi Nomor 10'],
#  'Ismail Bin Ibrahim': ['Hadits Muslim Nomor 10'],
#  "Ismail Bin Ja'Far": ['Hadits Muslim Nomor 12'],
#  'Ismail Bin Khalil': ['Hadits Darimi Nomor 15'],
#  'Israil': ['Hadits Ahmad Nomor 3'],
#  "Ja'Far": ['Hadits Nasai Nomor 14'],
#  "Ja'Far Bin Maimun At Tamimi": ['Hadits Darimi Nomor 12'],
#  "Ja'Far Bin Utsman Al Qurasyi": ['Hadits Darimi Nomor 14'],
#  'Jabir': ['Hadits Tirmidzi Nomor 24'],
#  'Jabir Bin Abdullah': ['Hadits Abu Daud Nomor 12'],
#  'Jarir': ['Hadits Muslim Nomor 11'],
#  'Kegaiban': ['Hadits Muslim Nomor 11'],
#  "Khalid Bin Ma'Dan": ['Hadits Darimi Nomor 13'],
#  'Khalid Bin Salamah': ['Hadits Abu Daud Nomor 17'],
#  'Lepaslah Suraqah': ['Hadits Ahmad Nomor 3'],
#  "Ma'Mar": ['Hadits Ibnu Majah Nomor 16', 'Hadits Nasai Nomor 22'],
#  'Maha Mengenal': ['Hadits Muslim Nomor 10', 'Hadits Muslim Nomor 11'],
#  'Maksud': ['Hadits Malik Nomor 16'],
#  'Malik': ['Hadits Ahmad Nomor 378',
#            'Hadits Malik Nomor 13',
#            'Hadits Malik Nomor 14',
#            'Hadits Malik Nomor 15',
#            'Hadits Malik Nomor 16',
#            'Hadits Malik Nomor 19',
#            'Hadits Malik Nomor 21',
#            'Hadits Malik Nomor 22',
#            'Hadits Muslim Nomor 12'],
#  'Malik Bin Anas': ['Hadits Muslim Nomor 12'],
#  'Manshur': ['Hadits Tirmidzi Nomor 13'],
#  'Mohonlah Al Afiyah': ['Hadits Ahmad Nomor 10'],
#  "Mu'Adz Bin Jabal": ['Hadits Nasai Nomor 4'],
#  "Mu'Awiyah": ['Hadits Ibnu Majah Nomor 18'],
#  'Muhammad': ['Hadits Ahmad Nomor 3'],
#  "Muhammad Bin 'Amru": ['Hadits Tirmidzi Nomor 22'],
#  'Muhammad Bin Abdullah Bin Numair': ['Hadits Muslim Nomor 10'],
#  'Muhammad Bin Abdullah Bin Yazid': ['Hadits Nasai Nomor 11'],
#  "Muhammad Bin Al 'Ala": ['Hadits Abu Daud Nomor 17'],
#  'Muhammad Bin Al Mutsanna': ['Hadits Abu Daud Nomor 16',
#                               'Hadits Bukhari Nomor 15'],
#  'Muhammad Bin Basysyar': ['Hadits Abu Daud Nomor 12'],
#  'Muhammad Bin Bisyr': ['Hadits Muslim Nomor 10'],
#  'Muhammad Bin Fudlail': ['Hadits Ahmad Nomor 14'],
#  'Muhammad Bin Ibrahim': ['Hadits Tirmidzi Nomor 22',
#                           'Hadits Tirmidzi Nomor 23'],
#  'Muhammad Bin Ishaq': ['Hadits Abu Daud Nomor 12',
#                         'Hadits Tirmidzi Nomor 22',
#                         'Hadits Tirmidzi Nomor 23'],
#  "Muhammad Bin Isma'Il": ['Hadits Tirmidzi Nomor 22',
#                           'Hadits Tirmidzi Nomor 25'],
#  'Muhammad Bin Manshur': ['Hadits Nasai Nomor 21'],
#  'Muhammad Bin Rumh Bin Al Muhajir Al Mishri': ['Hadits Ibnu Majah Nomor 15'],
#  "Muhammad Bin Syu'Aib": ['Hadits Ibnu Majah Nomor 10'],
#  'Muhammad Bin Yahya An Naisaburi': ['Hadits Ibnu Majah Nomor 16'],
#  'Muhammad Bin Yahya Bin Habban': ['Hadits Tirmidzi Nomor 11'],
#  'Muhammad Bin Yazid Al Hizami': ['Hadits Darimi Nomor 10'],
#  "Muhammad Shallallahu 'Alaihi Wasallam": ['Hadits Darimi Nomor 11'],
#  'Mujahid': ['Hadits Abu Daud Nomor 12'],
#  'Mujahid Bin Musa': ['Hadits Darimi Nomor 11'],
#  'Musa Bin Thalhah': ['Hadits Muslim Nomor 15'],
#  'Musaddad': ['Hadits Bukhari Nomor 12'],
#  "Mush'Ab Bin Umair Saudara Bani Abdud Dar": ['Hadits Ahmad Nomor 3'],
#  'Muslimin': ['Hadits Ahmad Nomor 14'],
#  'Nabi': ['Hadits Abu Daud Nomor 16', 'Hadits Ahmad Nomor 3'],
#  'Nabi Pembawa': ['Hadits Nasai Nomor 4'],
#  "Nabi Shallahu 'Alaihi Wa Sallam": ['Hadits Tirmidzi Nomor 11',
#                                      'Hadits Tirmidzi Nomor 12',
#                                      'Hadits Tirmidzi Nomor 13',
#                                      'Hadits Tirmidzi Nomor 22'],
#  "Nabi Shallallahu 'Alaihi Wasallam": ['Hadits Abu Daud Nomor 13',
#                                        'Hadits Abu Daud Nomor 15',
#                                        'Hadits Abu Daud Nomor 16',
#                                        'Hadits Abu Daud Nomor 18',
#                                        'Hadits Ahmad Nomor 11',
#                                        'Hadits Ahmad Nomor 377',
#                                        'Hadits Ahmad Nomor 378',
#                                        'Hadits Bukhari Nomor 12',
#                                        'Hadits Bukhari Nomor 14',
#                                        'Hadits Bukhari Nomor 15',
#                                        'Hadits Bukhari Nomor 16',
#                                        'Hadits Darimi Nomor 10',
#                                        'Hadits Darimi Nomor 11',
#                                        'Hadits Darimi Nomor 12',
#                                        'Hadits Darimi Nomor 15',
#                                        'Hadits Muslim Nomor 12',
#                                        'Hadits Muslim Nomor 13',
#                                        'Hadits Muslim Nomor 15',
#                                        'Hadits Muslim Nomor 20',
#                                        'Hadits Tirmidzi Nomor 22',
#                                        'Hadits Tirmidzi Nomor 24',
#                                        'Hadits Tirmidzi Nomor 25'],
#  "Nabiyullah Shallallahu 'Alaihi Wasallam": ['Hadits Abu Daud Nomor 12'],
#  "Nafi '": ['Hadits Abu Daud Nomor 15',
#             'Hadits Ahmad Nomor 378',
#             'Hadits Malik Nomor 15',
#             'Hadits Malik Nomor 16',
#             'Hadits Malik Nomor 21',
#             'Hadits Nasai Nomor 12',
#             'Hadits Tirmidzi Nomor 12'],
#  'Nashr Bin Ali': ['Hadits Abu Daud Nomor 18'],
#  'Nashr Bin Ali Al Jahdlami': ['Hadits Tirmidzi Nomor 25'],
#  'Neneknya': ['Hadits Tirmidzi Nomor 25'],
#  "Neneknya Binti Sa'Id Bin Zaid": ['Hadits Tirmidzi Nomor 25'],
#  "Nu'Aim Bin Hammad": ['Hadits Darimi Nomor 13'],
#  'Nubaih Bin Wahab': ['Hadits Ahmad Nomor 378'],
#  'Penduduk': ['Hadits Muslim Nomor 12'],
#  'Perawi': ['Hadits Muslim Nomor 12'],
#  'Qatadah': ['Hadits Abu Daud Nomor 16', 'Hadits Ibnu Majah Nomor 10'],
#  'Qotadah': ['Hadits Bukhari Nomor 12', 'Hadits Bukhari Nomor 14'],
#  'Quraisy': ['Hadits Ahmad Nomor 3'],
#  'Qutaibah': ['Hadits Nasai Nomor 14'],
#  "Qutaibah Bin Sa'Id Bin Jamil Bin Tharif Bin Abdullah Ats": ['Hadits Muslim '
#                                                               'Nomor 12'],
#  "Qutaibah Bin Sa'Id Semuanya": ['Hadits Muslim Nomor 12'],
#  'Rabah Bin Abdurrahman': ['Hadits Tirmidzi Nomor 25'],
#  'Rabah Bin Abdurrahman Bin Abu Sufyan Bin Huwaithib': ['Hadits Tirmidzi Nomor '
#                                                         '25'],
#  'Rabah Bin Abdurrahman Bin Abu Sufyan Bin Huwaittib': ['Hadits Tirmidzi Nomor '
#                                                         '25'],
#  'Rabah Bin Abdurrahman Namanya Abu Bakr Bin Huwaithib': ['Hadits Tirmidzi '
#                                                           'Nomor 25'],
#  "Rabi'Ah Al Jurasyi": ['Hadits Darimi Nomor 11'],
#  "Raihan Ibnu Sa'Id": ['Hadits Darimi Nomor 11'],
#  'Rasulullah': ['Hadits Ahmad Nomor 14',
#                 'Hadits Ahmad Nomor 3',
#                 'Hadits Darimi Nomor 13',
#                 'Hadits Darimi Nomor 14',
#                 'Hadits Ibnu Majah Nomor 15',
#                 'Hadits Ibnu Majah Nomor 19',
#                 'Hadits Muslim Nomor 13',
#                 'Hadits Muslim Nomor 16'],
#  'Rasulullah Minumlah': ['Hadits Ahmad Nomor 3'],
#  "Rasulullah Shallahu 'Alaihi Wa Sallam": ['Hadits Tirmidzi Nomor 22'],
#  "Rasulullah Shallallahu 'Alaihi Wasallam": ['Hadits Abu Daud Nomor 17',
#                                              'Hadits Ahmad Nomor 10',
#                                              'Hadits Ahmad Nomor 12',
#                                              'Hadits Ahmad Nomor 14',
#                                              'Hadits Ahmad Nomor 3',
#                                              'Hadits Ahmad Nomor 377',
#                                              'Hadits Bukhari Nomor 13',
#                                              'Hadits Bukhari Nomor 17',
#                                              'Hadits Darimi Nomor 10',
#                                              'Hadits Darimi Nomor 12',
#                                              'Hadits Darimi Nomor 13',
#                                              'Hadits Ibnu Majah Nomor 10',
#                                              'Hadits Ibnu Majah Nomor 14',
#                                              'Hadits Ibnu Majah Nomor 15',
#                                              'Hadits Ibnu Majah Nomor 16',
#                                              'Hadits Ibnu Majah Nomor 17',
#                                              'Hadits Ibnu Majah Nomor 18',
#                                              'Hadits Malik Nomor 14',
#                                              'Hadits Malik Nomor 22',
#                                              'Hadits Muslim Nomor 10',
#                                              'Hadits Muslim Nomor 11',
#                                              'Hadits Muslim Nomor 12',
#                                              'Hadits Muslim Nomor 13',
#                                              'Hadits Muslim Nomor 15',
#                                              'Hadits Muslim Nomor 16',
#                                              'Hadits Nasai Nomor 11',
#                                              'Hadits Nasai Nomor 12',
#                                              'Hadits Nasai Nomor 13',
#                                              'Hadits Nasai Nomor 14',
#                                              'Hadits Nasai Nomor 21',
#                                              'Hadits Nasai Nomor 22',
#                                              'Hadits Nasai Nomor 4',
#                                              'Hadits Tirmidzi Nomor 23',
#                                              'Hadits Tirmidzi Nomor 25'],
#  'Rasulullah Wafat': ['Hadits Ahmad Nomor 14'],
#  'Rauh': ['Hadits Ahmad Nomor 12'],
#  'Romawi': ['Hadits Ibnu Majah Nomor 18'],
#  "Sa'Ad Bin Thariq": ['Hadits Muslim Nomor 20'],
#  "Sa'Ad Bin Ubaidah As": ['Hadits Muslim Nomor 20'],
#  "Sa'Id": ['Hadits Abu Daud Nomor 16'],
#  "Sa'Id Bin Basyir": ['Hadits Ibnu Majah Nomor 10'],
#  "Sa'Id Bin Jubair": ['Hadits Ibnu Majah Nomor 17'],
#  "Sa'Id Bin Musayyab": ['Hadits Malik Nomor 22', 'Hadits Nasai Nomor 11'],
#  "Sa'Id Bin Zaid Bin 'Amru Bin Nufail": ['Hadits Tirmidzi Nomor 25'],
#  "Sa'Id Ibnul Musayyab": ['Hadits Tirmidzi Nomor 24'],
#  "Sahl Bin Sa'D": ['Hadits Tirmidzi Nomor 25'],
#  'Sahl Bin Utsman Al -Askari': ['Hadits Muslim Nomor 20'],
#  'Salim': ['Hadits Ibnu Majah Nomor 16'],
#  'Saudaraku': ['Hadits Darimi Nomor 13'],
#  'Sufyan': ['Hadits Abu Daud Nomor 15',
#             'Hadits Nasai Nomor 11',
#             'Hadits Nasai Nomor 21'],
#  'Sulaiman Bin Al -Mughirah': ['Hadits Muslim Nomor 13'],
#  'Suraqah': ['Hadits Ahmad Nomor 3'],
#  "Suraqah Bin Malik Bin Ju'Syum": ['Hadits Ahmad Nomor 3'],
#  'Syarik': ['Hadits Tirmidzi Nomor 12'],
#  "Syu'Aib": ['Hadits Bukhari Nomor 13', 'Hadits Bukhari Nomor 17'],
#  "Syu'Bah": ['Hadits Bukhari Nomor 12',
#              'Hadits Bukhari Nomor 14',
#              'Hadits Bukhari Nomor 16'],
#  'Tammam Bin Abbas': ['Hadits Tirmidzi Nomor 22'],
#  'Thalhah Bin Ubaidullah': ['Hadits Muslim Nomor 12'],
#  'Thalhah Bin Ubaidullah Berkata': ['Hadits Muslim Nomor 12'],
#  'Tsabit': ['Hadits Ahmad Nomor 11', 'Hadits Muslim Nomor 13'],
#  'Tsauban': ['Hadits Ibnu Majah Nomor 10'],
#  'Tsumamah Bin Hushain': ['Hadits Tirmidzi Nomor 25'],
#  'Tuntunlah': ['Hadits Malik Nomor 22'],
#  'Ubadah Bin Shamit Al Anshari': ['Hadits Ibnu Majah Nomor 18'],
#  'Ubaidah Adl Dlabbi': ['Hadits Tirmidzi Nomor 13'],
#  "Ubaidah Bin Mu'Attib Adl Dlabbi": ['Hadits Tirmidzi Nomor 13'],
#  'Ubaidullah': ['Hadits Tirmidzi Nomor 12'],
#  'Ubaidullah Bin Umar': ['Hadits Tirmidzi Nomor 11'],
#  'Umar': ['Hadits Ibnu Majah Nomor 18',
#           'Hadits Malik Nomor 19',
#           'Hadits Tirmidzi Nomor 12'],
#  'Umar Bin Al Khaththab': ['Hadits Ahmad Nomor 3'],
#  'Umar Bin Al Khatthab': ['Hadits Malik Nomor 19'],
#  'Umar Bin Khaththab': ['Hadits Ibnu Majah Nomor 18'],
#  "Umar Bin Sa'D": ['Hadits Abu Daud Nomor 15'],
#  "Umar Radliaallahu 'Anhu": ['Hadits Tirmidzi Nomor 12'],
#  'Umarah': ['Hadits Muslim Nomor 11'],
#  'Ummu Habibah': ['Hadits Tirmidzi Nomor 22'],
#  'Ummu Salamah': ['Hadits Tirmidzi Nomor 22'],
#  'Urwah Bin Az Zubair Bahwasanya Abdullah Bin Az Zubair': ['Hadits Ibnu Majah '
#                                                            'Nomor 15'],
#  'Utsman': ['Hadits Abu Daud Nomor 15'],
#  "Utsman Bin 'Affan": ['Hadits Malik Nomor 13'],
#  'Utsman Bin Urwah Bin Az Zubair': ['Hadits Darimi Nomor 14'],
#  'Wahai Abul Walid': ['Hadits Ibnu Majah Nomor 18'],
#  'Wahai Umar': ['Hadits Tirmidzi Nomor 12'],
#  'Wahb Bin Jarir': ['Hadits Abu Daud Nomor 12'],
#  "Waki '": ['Hadits Abu Daud Nomor 13', 'Hadits Tirmidzi Nomor 13'],
#  "Watsilah Al Asqa '": ['Hadits Tirmidzi Nomor 22'],
#  'Wuhaib': ['Hadits Muslim Nomor 16'],
#  "Ya'Qub Bin Ibrahim": ['Hadits Bukhari Nomor 14', 'Hadits Nasai Nomor 22'],
#  'Yahya': ['Hadits Bukhari Nomor 12',
#            'Hadits Malik Nomor 14',
#            'Hadits Malik Nomor 16',
#            'Hadits Malik Nomor 22'],
#  'Yahya Bin Ayyub': ['Hadits Muslim Nomor 12'],
#  'Yahya Bin Hamzah': ['Hadits Ibnu Majah Nomor 18'],
#  "Yahya Bin Sa'Id": ['Hadits Ahmad Nomor 377',
#                      'Hadits Ahmad Nomor 378',
#                      'Hadits Ibnu Majah Nomor 19',
#                      'Hadits Malik Nomor 19',
#                      'Hadits Muslim Nomor 16'],
#  'Yahya Bin Yahya At -Tamimi': ['Hadits Muslim Nomor 15'],
#  'Yahya Bin Zakariya': ['Hadits Muslim Nomor 20'],
#  'Yaman': ['Hadits Nasai Nomor 4'],
#  'Yazid Bin Harun': ['Hadits Tirmidzi Nomor 25'],
#  'Yazid Bin Iyadl': ['Hadits Tirmidzi Nomor 25'],
#  'Yusuf Bin Shuhaib': ['Hadits Nasai Nomor 13'],
#  'Zaid Bin Arqam': ['Hadits Nasai Nomor 13'],
#  'Zaid Bin Khalid': ['Hadits Tirmidzi Nomor 22', 'Hadits Tirmidzi Nomor 23'],
#  'Zaid Bin Khalid Al Juhani': ['Hadits Tirmidzi Nomor 23'],
#  "Ziyad Bin Sa'Ad": ['Hadits Abu Daud Nomor 18'],
#  'Zubair': ['Hadits Ibnu Majah Nomor 15'],
#  'Zuhair': ['Hadits Muslim Nomor 10'],
#  'Zuhair Bin Harb': ['Hadits Abu Daud Nomor 13',
#                      'Hadits Muslim Nomor 10',
#                      'Hadits Muslim Nomor 11'],
#  'Zuhri': ['Hadits Nasai Nomor 11']}

# %%
"asdasd asd".title()
# Out:
# 'Asdasd Asd'

# %%
# print(df_test['title'].unique())

# %%
# df_train_cp = df_train.copy()
# df_train_cp['predicted'] = clf.predict(X_train)

# y_pred_tr = df_train_cp.groupby('title')['predicted']
# y_true_tr = df_train_cp.groupby('title')['entity']

# y_grouped_pred_tr = [p[1].tolist() for p in y_pred_tr]
# y_grouped_true_tr = [p[1].tolist() for p in y_true_tr]

# print(seq_met(y_grouped_true_tr, y_grouped_pred_tr))
