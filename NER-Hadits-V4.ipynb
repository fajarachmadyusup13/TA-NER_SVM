# %%
import string
import pandas as pd
import numpy as np
from pprint import pprint
from pprint import pprint
from sklearn.svm import LinearSVC, SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from seqeval.metrics import classification_report as seq_met
from sklearn.metrics import classification_report as skl_met
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ## Read Test and Train Data

# %%
df_train = pd.read_excel("Datasets/dataset.xlsx", sheetname="train")
df_test = pd.read_excel("Datasets/dataset.xlsx", sheetname="test")
# Out:
# /home/ghost/anaconda3/envs/Playgrounds/lib/python3.7/site-packages/pandas/util/_decorators.py:188: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)

# %%
# Count the tokens for each entity
df_test.groupby('entity').size().reset_index(name='counts')
# Out:
#   entity  counts
# 0  B-LOC       6
# 1  B-PER     677
# 2  I-LOC       2
# 3  I-PER    1386
# 4      O    7795

# %%
# Count the tokens for each entity
df_train.groupby('entity').size().reset_index(name='counts')
# Out:
#   entity  counts
# 0  B-LOC      24
# 1  B-PER    1564
# 2  I-LOC      22
# 3  I-PER    3067
# 4      O   16466

# %% [markdown]
# ## Grouping Tokens by Hadith

# %%
def sencentes_getter(data):
    agg_func = lambda s: [(s.name, t, p, e) for t, p, e in zip(s['token'].values.tolist(), 
                                                           s['pos'].values.tolist(), 
                                                           s['entity'].values.tolist())]
    grouped = data.groupby('title').apply(agg_func)
    sentences = [s for s in grouped]
    
    return sentences

# %%
train_sents = sencentes_getter(df_train)
test_sents = sencentes_getter(df_test)

# %% [markdown]
# ## Feature Extraction

# %%
def word2features(sent, i):
        word = sent[i][1]
        postag = sent[i][2]

        features = {
            'bias': 1.0, 
            'word': word,
            'word[-3:]': word[-3:],
            'word[-2:]': word[-2:],
            'word[-1:]': word[-1:],
            'word[:3]': word[:3],
            'word[:2]': word[:2],
            'word[:1]': word[:1],            
            'word.islower()': word.islower(),
            'word.istitle()': word.istitle(),
            'postag': postag,
            
            'word_pls_1': '',
            'word_pls_1[-3:]': '',
            'word_pls_1[-2:]': '',
            'word_pls_1[-1:]': '',
            'word_pls_1[:3]': '',
            'word_pls_1[:2]': '',
            'word_pls_1[:1]': '',
            'word_pls_1.islower()': False,
            'word_pls_1.istitle()': False,
            'postag_pls_1': '',
            
            'word_min_1': '',
            'word_min_1[-3:]': '',
            'word_min_1[-2:]': '',
            'word_min_1[-1:]': '',
            'word_min_1[:3]': '',
            'word_min_1[:2]': '',
            'word_min_1[:1]': '',
            'word_min_1.islower()': False,
            'word_min_1.istitle()': False,
            'postag_min_1': '',
            
            'BOS': True if i == 0 else False,
            'EOS': True if i == len(sent)-1 else False,
        }
        
        
        if i < len(sent)-1:
            word_pls_1 = sent[i+1][1]
            postag_pls_1 = sent[i+1][2]
            features.update({
                'word_pls_1': word_pls_1,
                'word_pls_1[-3:]': word_pls_1[-3:],
                'word_pls_1[-2:]': word_pls_1[-2:],
                'word_pls_1[-1:]': word_pls_1[-1:],
                'word_pls_1[:3]': word_pls_1[:3],
                'word_pls_1[:2]': word_pls_1[:2],
                'word_pls_1[:1]': word_pls_1[:1],
                'word_pls_1.islower()': word_pls_1.islower(),
                'word_pls_1.istitle()': word_pls_1.istitle(),
                'postag_pls_1': postag_pls_1
            })
        if i > 0:
            word_min_1 = sent[i-1][1]
            postag_min_1 = sent[i-1][2]
            features.update({
                'word_min_1': word_min_1,
                'word_min_1[-3:]': word_min_1[-3:],
                'word_min_1[-2:]': word_min_1[-2:],
                'word_min_1[-1:]': word_min_1[-1:],
                'word_min_1[:3]': word_min_1[:3],
                'word_min_1[:2]': word_min_1[:2],
                'word_min_1[:1]': word_min_1[:1],
                'word_min_1.islower()': word_min_1.islower(),
                'word_min_1.istitle()': word_min_1.istitle(),
                'postag_min_1': postag_min_1
            })
        
        return features

def sent2features(sent):  
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
#     print(sent)
    return [label for title, token, postag, label in sent]

def sent2labelspred(sent):
    return [pred for title, token, postag, label, pred in sent]

# %%
# Training
X_train = [x for s in train_sents for x in sent2features(s)]
y_train = [y for s in train_sents for y in sent2labels(s)]

# Test
X_test = [x for s in test_sents for x in sent2features(s)]
y_test = [y for s in test_sents for y in sent2labels(s)]

# %%
classes = ['B-LOC', 'B-PER', 'I-LOC', 'I-PER', 'O']
new_classes = classes.copy()
new_classes.pop()
# Out:
# 'O'

# %%
pd.DataFrame(X_train)
# Out:
#          BOS    EOS  bias postag postag_min_1 postag_pls_1          word  \
# 0       True  False   1.0    ADV                      VERB         Telah
# 1      False  False   1.0   VERB          ADV          ADP  menceritakan
# 2      False  False   1.0    ADP         VERB         PRON        kepada
# 3      False  False   1.0   PRON          ADP        PROPN          kami
# 4      False  False   1.0  PROPN         PRON        PROPN      Abdullah
# 5      False  False   1.0  PROPN        PROPN        PROPN           bin
# 6      False  False   1.0  PROPN        PROPN        PROPN      Maslamah
# 7      False  False   1.0  PROPN        PROPN        PROPN           bin
# 8      False  False   1.0  PROPN        PROPN        PROPN        Qa'nab
# 9      False  False   1.0  PROPN        PROPN        PROPN            al
# 10     False  False   1.0  PROPN        PROPN          ADV       Qa'nabi
# 11     False  False   1.0    ADV        PROPN         VERB         telah
# 12     False  False   1.0   VERB          ADV          ADP  menceritakan
# 13     False  False   1.0    ADP         VERB         PRON        kepada
# 14     False  False   1.0   PRON          ADP        PROPN          kami
# 15     False  False   1.0  PROPN         PRON        PROPN         Abdul
# 16     False  False   1.0  PROPN        PROPN          ADV          Aziz
# 17     False  False   1.0    ADV        PROPN        PROPN         yakni
# 18     False  False   1.0  PROPN          ADV        PROPN           bin
# 19     False  False   1.0  PROPN        PROPN          ADP      Muhammad
# 20     False  False   1.0    ADP        PROPN        PROPN          dari
# 21     False  False   1.0  PROPN          ADP          ADV      Muhammad
# 22     False  False   1.0    ADV        PROPN        PROPN         yakni
# 23     False  False   1.0  PROPN          ADV        PROPN           bin
# 24     False  False   1.0  PROPN        PROPN          ADP          Amru
# 25     False  False   1.0    ADP        PROPN        PROPN          dari
# 26     False  False   1.0  PROPN          ADP        PROPN           Abu
# 27     False  False   1.0  PROPN        PROPN          ADP       Salamah
# 28     False  False   1.0    ADP        PROPN        PROPN          dari
# 29     False  False   1.0  PROPN          ADP        PROPN            Al
# ...      ...    ...   ...    ...          ...          ...           ...
# 21113  False  False   1.0   NOUN         VERB          ADP       riwayat
# 21114  False  False   1.0    ADP         NOUN        PROPN          dari
# 21115  False  False   1.0  PROPN          ADP        PROPN           Abu
# 21116  False  False   1.0  PROPN        PROPN        PUNCT       Qatadah
# 21117  False  False   1.0  PUNCT        PROPN        PROPN             ,
# 21118  False  False   1.0  PROPN        PUNCT         CONJ        Aisyah
# 21119  False  False   1.0   CONJ        PROPN        PROPN           dan
# 21120  False  False   1.0  PROPN         CONJ        PROPN         Ammar
# 21121  False  False   1.0  PROPN        PROPN        PROPN           bin
# 21122  False  False   1.0  PROPN        PROPN        PUNCT         Yasir
# 21123  False  False   1.0  PUNCT        PROPN        PUNCT             .
# 21124  False  False   1.0  PUNCT        PUNCT        PROPN             "
# 21125  False  False   1.0  PROPN        PUNCT        PROPN           Abu
# 21126  False  False   1.0  PROPN        PROPN         VERB           Isa
# 21127  False  False   1.0   VERB        PROPN        PUNCT       berkata
# 21128  False  False   1.0  PUNCT         VERB        PUNCT             ;
# 21129  False  False   1.0  PUNCT        PUNCT          ADP             "
# 21130  False  False   1.0    ADP        PUNCT         NOUN         Dalam
# 21131  False  False   1.0   NOUN          ADP          DET           bab
# 21132  False  False   1.0    DET         NOUN        PUNCT           ini
# 21133  False  False   1.0  PUNCT          DET         NOUN             ,
# 21134  False  False   1.0   NOUN        PUNCT         NOUN        hadits
# 21135  False  False   1.0   NOUN         NOUN        PROPN       riwayat
# 21136  False  False   1.0  PROPN         NOUN         NOUN         Jabir
# 21137  False  False   1.0   NOUN        PROPN         VERB    derajatnya
# 21138  False  False   1.0   VERB         NOUN         NOUN        adalah
# 21139  False  False   1.0   NOUN         VERB          NUM         hasan
# 21140  False  False   1.0    NUM         NOUN        PUNCT        gharib
# 21141  False  False   1.0  PUNCT          NUM        PUNCT             .
# 21142  False   True   1.0  PUNCT        PUNCT                          "
#
#        word.islower()  word.istitle() word[-1:]  ... word_min_1[:3]  \
# 0               False            True         h  ...
# 1                True           False         n  ...            Tel
# 2                True           False         a  ...            men
# 3                True           False         i  ...            kep
# 4               False            True         h  ...            kam
# 5                True           False         n  ...            Abd
# 6               False            True         h  ...            bin
# 7                True           False         n  ...            Mas
# 8               False           False         b  ...            bin
# 9                True           False         l  ...            Qa'
# 10              False           False         i  ...             al
# 11               True           False         h  ...            Qa'
# 12               True           False         n  ...            tel
# 13               True           False         a  ...            men
# 14               True           False         i  ...            kep
# 15              False            True         l  ...            kam
# 16              False            True         z  ...            Abd
# 17               True           False         i  ...            Azi
# 18               True           False         n  ...            yak
# 19              False            True         d  ...            bin
# 20               True           False         i  ...            Muh
# 21              False            True         d  ...            dar
# 22               True           False         i  ...            Muh
# 23               True           False         n  ...            yak
# 24              False            True         u  ...            bin
# 25               True           False         i  ...            Amr
# 26              False            True         u  ...            dar
# 27              False            True         h  ...            Abu
# 28               True           False         i  ...            Sal
# 29              False            True         l  ...            dar
# ...               ...             ...       ...  ...            ...
# 21113            True           False         t  ...            ada
# 21114            True           False         i  ...            riw
# 21115           False            True         u  ...            dar
# 21116           False            True         h  ...            Abu
# 21117           False           False         ,  ...            Qat
# 21118           False            True         h  ...              ,
# 21119            True           False         n  ...            Ais
# 21120           False            True         r  ...            dan
# 21121            True           False         n  ...            Amm
# 21122           False            True         r  ...            bin
# 21123           False           False         .  ...            Yas
# 21124           False           False         "  ...              .
# 21125           False            True         u  ...              "
# 21126           False            True         a  ...            Abu
# 21127            True           False         a  ...            Isa
# 21128           False           False         ;  ...            ber
# 21129           False           False         "  ...              ;
# 21130           False            True         m  ...              "
# 21131            True           False         b  ...            Dal
# 21132            True           False         i  ...            bab
# 21133           False           False         ,  ...            ini
# 21134            True           False         s  ...              ,
# 21135            True           False         t  ...            had
# 21136           False            True         r  ...            riw
# 21137            True           False         a  ...            Jab
# 21138            True           False         h  ...            der
# 21139            True           False         n  ...            ada
# 21140            True           False         b  ...            has
# 21141           False           False         .  ...            gha
# 21142           False           False         "  ...              .
#
#          word_pls_1 word_pls_1.islower() word_pls_1.istitle() word_pls_1[-1:]  \
# 0      menceritakan                 True                False               n
# 1            kepada                 True                False               a
# 2              kami                 True                False               i
# 3          Abdullah                False                 True               h
# 4               bin                 True                False               n
# 5          Maslamah                False                 True               h
# 6               bin                 True                False               n
# 7            Qa'nab                False                False               b
# 8                al                 True                False               l
# 9           Qa'nabi                False                False               i
# 10            telah                 True                False               h
# 11     menceritakan                 True                False               n
# 12           kepada                 True                False               a
# 13             kami                 True                False               i
# 14            Abdul                False                 True               l
# 15             Aziz                False                 True               z
# 16            yakni                 True                False               i
# 17              bin                 True                False               n
# 18         Muhammad                False                 True               d
# 19             dari                 True                False               i
# 20         Muhammad                False                 True               d
# 21            yakni                 True                False               i
# 22              bin                 True                False               n
# 23             Amru                False                 True               u
# 24             dari                 True                False               i
# 25              Abu                False                 True               u
# 26          Salamah                False                 True               h
# 27             dari                 True                False               i
# 28               Al                False                 True               l
# 29         Mughirah                False                 True               h
# ...             ...                  ...                  ...             ...
# 21113          dari                 True                False               i
# 21114           Abu                False                 True               u
# 21115       Qatadah                False                 True               h
# 21116             ,                False                False               ,
# 21117        Aisyah                False                 True               h
# 21118           dan                 True                False               n
# 21119         Ammar                False                 True               r
# 21120           bin                 True                False               n
# 21121         Yasir                False                 True               r
# 21122             .                False                False               .
# 21123             "                False                False               "
# 21124           Abu                False                 True               u
# 21125           Isa                False                 True               a
# 21126       berkata                 True                False               a
# 21127             ;                False                False               ;
# 21128             "                False                False               "
# 21129         Dalam                False                 True               m
# 21130           bab                 True                False               b
# 21131           ini                 True                False               i
# 21132             ,                False                False               ,
# 21133        hadits                 True                False               s
# 21134       riwayat                 True                False               t
# 21135         Jabir                False                 True               r
# 21136    derajatnya                 True                False               a
# 21137        adalah                 True                False               h
# 21138         hasan                 True                False               n
# 21139        gharib                 True                False               b
# 21140             .                False                False               .
# 21141             "                False                False               "
# 21142                              False                False
#
#       word_pls_1[-2:]  word_pls_1[-3:]  word_pls_1[:1] word_pls_1[:2]  \
# 0                  an              kan               m             me
# 1                  da              ada               k             ke
# 2                  mi              ami               k             ka
# 3                  ah              lah               A             Ab
# 4                  in              bin               b             bi
# 5                  ah              mah               M             Ma
# 6                  in              bin               b             bi
# 7                  ab              nab               Q             Qa
# 8                  al               al               a             al
# 9                  bi              abi               Q             Qa
# 10                 ah              lah               t             te
# 11                 an              kan               m             me
# 12                 da              ada               k             ke
# 13                 mi              ami               k             ka
# 14                 ul              dul               A             Ab
# 15                 iz              ziz               A             Az
# 16                 ni              kni               y             ya
# 17                 in              bin               b             bi
# 18                 ad              mad               M             Mu
# 19                 ri              ari               d             da
# 20                 ad              mad               M             Mu
# 21                 ni              kni               y             ya
# 22                 in              bin               b             bi
# 23                 ru              mru               A             Am
# 24                 ri              ari               d             da
# 25                 bu              Abu               A             Ab
# 26                 ah              mah               S             Sa
# 27                 ri              ari               d             da
# 28                 Al               Al               A             Al
# 29                 ah              rah               M             Mu
# ...               ...              ...             ...            ...
# 21113              ri              ari               d             da
# 21114              bu              Abu               A             Ab
# 21115              ah              dah               Q             Qa
# 21116               ,                ,               ,              ,
# 21117              ah              yah               A             Ai
# 21118              an              dan               d             da
# 21119              ar              mar               A             Am
# 21120              in              bin               b             bi
# 21121              ir              sir               Y             Ya
# 21122               .                .               .              .
# 21123               "                "               "              "
# 21124              bu              Abu               A             Ab
# 21125              sa              Isa               I             Is
# 21126              ta              ata               b             be
# 21127               ;                ;               ;              ;
# 21128               "                "               "              "
# 21129              am              lam               D             Da
# 21130              ab              bab               b             ba
# 21131              ni              ini               i             in
# 21132               ,                ,               ,              ,
# 21133              ts              its               h             ha
# 21134              at              yat               r             ri
# 21135              ir              bir               J             Ja
# 21136              ya              nya               d             de
# 21137              ah              lah               a             ad
# 21138              an              san               h             ha
# 21139              ib              rib               g             gh
# 21140               .                .               .              .
# 21141               "                "               "              "
# 21142
#
#       word_pls_1[:3]
# 0                men
# 1                kep
# 2                kam
# 3                Abd
# 4                bin
# 5                Mas
# 6                bin
# 7                Qa'
# 8                 al
# 9                Qa'
# 10               tel
# 11               men
# 12               kep
# 13               kam
# 14               Abd
# 15               Azi
# 16               yak
# 17               bin
# 18               Muh
# 19               dar
# 20               Muh
# 21               yak
# 22               bin
# 23               Amr
# 24               dar
# 25               Abu
# 26               Sal
# 27               dar
# 28                Al
# 29               Mug
# ...              ...
# 21113            dar
# 21114            Abu
# 21115            Qat
# 21116              ,
# 21117            Ais
# 21118            dan
# 21119            Amm
# 21120            bin
# 21121            Yas
# 21122              .
# 21123              "
# 21124            Abu
# 21125            Isa
# 21126            ber
# 21127              ;
# 21128              "
# 21129            Dal
# 21130            bab
# 21131            ini
# 21132              ,
# 21133            had
# 21134            riw
# 21135            Jab
# 21136            der
# 21137            ada
# 21138            has
# 21139            gha
# 21140              .
# 21141              "
# 21142
#
# [21143 rows x 33 columns]

# %% [markdown]
# ## Training Model

# %%
clf = Pipeline([
    ('vectorizer', DictVectorizer(sparse=False)),
    ('classifier', LinearSVC(multi_class='ovr'))
])

clf.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('vectorizer', DictVectorizer(dtype=<class 'numpy.float64'>, separator='=', sort=True,
#         sparse=False)), ('classifier', LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0))])

# %%
print("Accuracy of Training:")
print(clf.score(X_train, y_train))
print("Accuracy of Validation:")
print(clf.score(X_test, y_test))

type(skl_met(y_test, clf.predict(X_test), labels=new_classes))
# Out:
# Accuracy of Training:
# 0.9966419145816582
# Accuracy of Validation:
# 0.9869247922156903
# str

# %%
df_result = df_test.copy()
df_result['predicted'] = clf.predict(X_test)
df_result_grouped = df_result.groupby('title')

y_pred = df_result_grouped['predicted']
y_true = df_result_grouped['entity']

y_grouped_pred = [p[1].tolist() for p in y_pred]
y_grouped_true = [p[1].tolist() for p in y_true]


# print(df_result_grouped)
print(seq_met(y_grouped_true, y_grouped_pred))
# ne_per = 2251
# ne_loc = 41
print("Training Data")
print("Jumlah Hadits: ", 140)
print("Jumlah Entitas PER: ", 1572)
print("Jumlah Entitas LOC: ", 33)
print("\n")
print("Test Data")
print("Jumlah Hadits: ", 60)
print("Jumlah Entitas PER: ", 679)
print("Jumlah Entitas LOC: ", 8)
# Out:
#              precision    recall  f1-score   support
#
#         PER       0.88      0.91      0.89       678
#         LOC       0.27      0.38      0.32         8
#
# avg / total       0.87      0.91      0.89       686
#
# Training Data
# Jumlah Hadits:  140
# Jumlah Entitas PER:  1572
# Jumlah Entitas LOC:  33
#
#
# Test Data
# Jumlah Hadits:  60
# Jumlah Entitas PER:  679
# Jumlah Entitas LOC:  8

# %%
def get_predicted_sent(data):
    func = lambda s: [(s.name, t, p) for t, p in zip(s['token'].values.tolist(),
                                                     s['predicted'].values.tolist())]
    groupedx = data.groupby('title').apply(func)
    sents = [g for g in groupedx]
    
    return sents

# %%
from pandas import ExcelWriter

pred_sents = get_predicted_sent(df_result)
writer = ExcelWriter('Datasets/result_tes.xlsx')
df_result.to_excel(writer, 'result', index=False)
writer.save()

def names_by_hadith(data):
    titl = {}
    sent_nes = []

    for sent in data:
        for i in range(len(sent)):
            if sent[i][-1] == 'B-PER':
                ne = []
                while sent[i][-1] != 'O':
                    ne.append(sent[i][1])
                    if i<len(sent)-1:
                        i+=1
                    else:
                        break
                str_name = "".join([i+" " if not i.startswith("'") and i not in string.punctuation else i for i in ne]).strip()
                if str_name not in sent_nes:
                    sent_nes.append(str_name)
        titl[sent[0][0]] = sent_nes.copy()
        sent_nes.clear()
    return titl

# pprint(names_by_hadith(pred_sents))

# %% [raw]
# def hadith_by_name(data):
#     nms = {}
#     for sent in data:
#         for i in range(len(sent)):
#             if sent[i][-1] == 'B-PER':
#                 ne = []
#                 while sent[i][-1] != 'O':
#                     ne.append(sent[i][1])
#                     if i<len(sent)-1:
#                         i+=1
#                     else:
#                         break
#                 str_name = "".join([i+" "
#                                     if not i.startswith("'") and i not in string.punctuation
#                                     else i for i in ne]).strip().title()
#                 if str_name not in nms:
#                     nms[str_name] = [sent[0][0]]
#                 else:
#                     if sent[0][0] not in nms[str_name]:
#                         nms[str_name].append(sent[0][0])
#     return nms
#
# pprint(hadith_by_name(pred_sents))

# %%
df_result = df_test.copy()
df_result['predicted'] = clf.predict(X_test)

# %%
# df_result

# %%
writer = ExcelWriter('res.xlsx')
df_result.to_excel(writer,'Sheet1',index=False)
writer.save()

# %%
# print(df_test['title'].unique())

# %%
df_train_cp = df_train.copy()
df_train_cp['predicted'] = clf.predict(X_train)

y_pred_tr = df_train_cp.groupby('title')['predicted']
y_true_tr = df_train_cp.groupby('title')['entity']

y_grouped_pred_tr = [p[1].tolist() for p in y_pred_tr]
y_grouped_true_tr = [p[1].tolist() for p in y_true_tr]

print(seq_met(y_grouped_true_tr, y_grouped_pred_tr))
# Out:
#              precision    recall  f1-score   support
#
#         PER       0.97      0.98      0.98      1572
#         LOC       0.96      0.82      0.89        33
#
# avg / total       0.97      0.98      0.98      1605

# %% [raw]
# read_merged = pd.read_excel("result.xlsx", sheetname="result")
# y = read_merged.entity.values

# %% [raw]
# unique, counts = np.unique(y, return_counts=True)

# %% [raw]
# print(unique)
# print(counts)

# %% [raw]
# new_unique = list(unique.copy())
# new_counts = list(counts.copy())
#
# new_unique = [new_unique[1], new_unique[-2],new_unique[-1]]
# new_counts = [new_counts[1], new_counts[-2], new_counts[-1]]

# %% [raw]
# new_unique

# %% [raw]
# new_counts

# %% [raw]
# import matplotlib.pyplot as plt
#
# plt.bar(new_unique, new_counts, 1)
# plt.title('Class Frequency')
# plt.xlabel('Class')
# plt.ylabel('Frequency')
# plt.show()

# %% [raw]
# y_true = [['B-PER', 'I-PER', 'I-PER', 'O','B-PER','I-PER','I-PER','I-PER']]
# y_pred = [['B-PER', 'I-PER', 'I-PER', 'I-PER','B-PER','I-PER','I-PER','I-PER']]
#
# print(seq_met(y_true, y_pred))

# %% [raw]
# df = pd.read_excel("result.xlsx")
# x = [(e,p) for e, p in zip(df['entity'].values.tolist(),
#                       df['predicted'].values.tolist())
#     if (e == 'O' and p == 'O') or (e == 'O' and p == 'B-LOC') or (e == 'O' and p == 'I-LOC') or
#     (e == 'B-LOC' and p == 'O') or (e == 'I-LOC' and p == 'O') or (e == 'B-LOC' and p == 'I-LOC') or
#      (e == 'I-LOC' and p == 'B-LOC') or (e == 'B-LOC' and p == 'B-LOC') or (e == 'I-LOC' and p == 'I-LOC')]

# %% [raw]
# len(x)

# %% [raw]
# np.where(pd.isnull(read_merged['entity']))
